# %%
sorted({
     'all',
     'bushel','bushels',
     'c',
     'chopped',
     'clove','cloves',
     'coarse','coarsely',
     'crumbled',
     'cup','cups',
     'dash','dashes',
     'diced',
     'drop','drops',
     'extra',
     'finely',
     'fl. oz',
     'fresh','freshly',
     'g',
     'gallon','gallons',
     'glass','glasses',
     'gram','grams',
     'grated',
     'kg','kgs',
     'lb','lbs',
     'liter','liters',
     'lrg','large',
     'mashed',
     'med','medium',
     'ml','mls',
     'ounce','ounces','oz',
     'pasta',
     'pinch','pinches',
     'pint','pints',
     'pound','pounds',
     'purpose',
     'qt',
     'quart','quarts',
     'scoop','scoops',
     'shot','shots',
     'shredded',
     'sifted',
     'sliced',
     'sm','small',
     'tablespoon','tablespoons','tbs','tbsp','tbsps',
     'teaspoon','teaspoons','tsp','tsps',
     'thin','thinly',
     'to',
     'white','whites',
     'whole',
     'x',
     'yolk','yolks'
})
# Out:
# ['all',
#  'bushel',
#  'bushels',
#  'c',
#  'chopped',
#  'clove',
#  'cloves',
#  'coarse',
#  'coarsely',
#  'crumbled',
#  'cup',
#  'cups',
#  'dash',
#  'dashes',
#  'diced',
#  'drop',
#  'drops',
#  'extra',
#  'finely',
#  'fl. oz',
#  'fresh',
#  'freshly',
#  'g',
#  'gallon',
#  'gallons',
#  'glass',
#  'glasses',
#  'gram',
#  'grams',
#  'grated',
#  'kg',
#  'large',
#  'lb',
#  'lbs',
#  'liter',
#  'liters',
#  'lrg',
#  'mashed',
#  'medium',
#  'ml',
#  'ounce',
#  'ounces',
#  'oz',
#  'pasta',
#  'pinch',
#  'pinches',
#  'pint',
#  'pints',
#  'pound',
#  'pounds',
#  'purpose',
#  'qt',
#  'quart',
#  'quarts',
#  'scoop',
#  'scoops',
#  'shot',
#  'shots',
#  'shredded',
#  'sifted',
#  'sliced',
#  'sm',
#  'small',
#  'tablespoon',
#  'tablespoons',
#  'tbs',
#  'tbsp',
#  'tbsps',
#  'teaspoon',
#  'teaspoons',
#  'thin',
#  'thinly',
#  'to',
#  'tsp',
#  'tsps',
#  'white',
#  'whites',
#  'whole',
#  'x',
#  'yolk',
#  'yolks']
