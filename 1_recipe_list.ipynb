# %%
import pandas as pd
import pickle

# %%
df = pd.read_json('data/recipe1M_layers/layer1.json')[['title','url']]
df
# Out:
#                                                      title  \
# 0                               Worlds Best Mac and Cheese
# 1                              Dilly Macaroni Salad Recipe
# 2                                                 Gazpacho
# 3                                Crunchy Onion Potato Bake
# 4                       Cool 'n Easy Creamy Watermelon Pie
# ...                                                    ...
# 1029715                   Baumkuchen -- the King of Cakes!
# 1029716      Extremely Easy and Quick - Namul Daikon Salad
# 1029717         Pan-Roasted Pork Chops With Apple Fritters
# 1029718                     Polpette in Spicy Tomato Sauce
# 1029719  Mexican-Style Sweetened Black Coffee (Cafe de ...
#
#                                                        url
# 0        http://www.epicurious.com/recipes/food/views/-...
# 1        http://cookeatshare.com/recipes/dilly-macaroni...
# 2        http://www.foodnetwork.com/recipes/gazpacho1.html
# ...

# %%
with open('title_url.pickle', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('title_url.pickle', 'rb') as f:
    df_2 = pickle.load(f)

# %%
df_2
# Out:
#                                                      title  \
# 0                               Worlds Best Mac and Cheese
# 1                              Dilly Macaroni Salad Recipe
# 2                                                 Gazpacho
# 3                                Crunchy Onion Potato Bake
# 4                       Cool 'n Easy Creamy Watermelon Pie
# ...                                                    ...
# 1029715                   Baumkuchen -- the King of Cakes!
# 1029716      Extremely Easy and Quick - Namul Daikon Salad
# 1029717         Pan-Roasted Pork Chops With Apple Fritters
# 1029718                     Polpette in Spicy Tomato Sauce
# 1029719  Mexican-Style Sweetened Black Coffee (Cafe de ...
#
#                                                        url
# 0        http://www.epicurious.com/recipes/food/views/-...
# 1        http://cookeatshare.com/recipes/dilly-macaroni...
# 2        http://www.foodnetwork.com/recipes/gazpacho1.html
# ...
